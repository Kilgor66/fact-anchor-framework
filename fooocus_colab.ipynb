# %% [markdown]
# <a href="https://colab.research.google.com/github/Kilgor66/fact-anchor-framework/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive

# 1. Drive csatlakoztatása
drive.mount('/content/drive')

# 2. Python 3.10 virtuális környezet előkészítése a helyi lemezen
# !apt-get update -y > /dev/null 2>&1
# !apt-get install -y python3.10 python3.10-venv > /dev/null 2>&1
# !python3.10 -m venv /content/env

# 3. Függőségek és FastAPI verzió rögzítése
# !source /content/env/bin/activate && pip install -q -U pip setuptools
# !source /content/env/bin/activate && pip install -q -r /content/drive/MyDrive/Fooocus/requirements_versions.txt
# !source /content/env/bin/activate && pip install -q fastapi==0.111.1

# HÁLÓZATI HIBA JAVÍTÁSA: A Gradio 3s-os ellenőrzési korlátjának növelése 30s-ra
# !sed -i 's/timeout=3/timeout=30/g' /content/env/lib/python3.10/site-packages/gradio/networking.py

# 4. Belépés a mappába és fájlok előkészítése
# %cd /content/drive/MyDrive/Fooocus

# A no_init_weights hiba sebészi javítása
# !git checkout modules/patch_clip.py > /dev/null 2>&1
# !sed -i 's/with modeling_utils.no_init_weights():/if True:/g' modules/patch_clip.py

# Az új modell beállítása alapértelmezettként indításkor
# !git checkout presets/default.json > /dev/null 2>&1
# !sed -i 's/juggernautXL_v8Rundiffusion.safetensors/talmendoxlSDXL_v11Beta.safetensors/g' presets/default.json

# 5. Indítás
# !source /content/env/bin/activate && unset MPLBACKEND && python entry_with_update.py --share --always-high-vram
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Jul 15 2026, 23:40:17) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Total VRAM 14913 MB, total RAM 12976 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://bf7f5e483320240bfe.gradio.live
#
# ...
